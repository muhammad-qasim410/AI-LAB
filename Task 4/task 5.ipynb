# %%
#num1 = 0
#num2 =1
#count = 10
#n =50
#while True:
 #  print(num1, end="")
  # if num2>n:
   # break
    
   #num1,num2 =num2,num1+num2
num1 = 0
num2 =1
def fib_series(num1,num2,n):

 while True: 
    print(num1, end="")
    if num2>n:
        return
    
    num1,num2 =num2,num1+num2
fib_series(num1,num2,20)
# Out:
# 011235813

# %%
tree ={
    "A":["B","C"],
    "B":["D","E"],
    "C":["F"],
    "D":[],
    "E":[],
    "F":["G"],
    "G":[]
}

visited = list()

def dfs(start,goal):
    if goal not in visited:
        visited.append(start) 
    #print(start, end=":")
        for child in tree[start]:
            dfs(child,goal)
        

dfs("A","F")

# %%
print(visited)
# Out:
# ['A', 'B', 'D', 'E', 'C', 'F']
